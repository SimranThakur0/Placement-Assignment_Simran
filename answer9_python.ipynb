# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read the data from the CSV file
data_url = "https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD"
df = pd.read_csv(data_url)

# Get all the cars and their types that do not qualify for clean alternative fuel vehicle
non_cafv_cars = []
for car in data:
    if car[1] != "CLEAN ALTERNATIVE FUEL VEHICLE":
        non_cafv_cars.append(car)

# Get all TESLA cars with the model year, and model type made in Bothell City.
tesla_cars = []
for car in data:
    if car[0] == "TESLA":
        if car[3] == "BOTHELL":
            tesla_cars.append(car)

# Get all the cars that have an electric range of more than 100, and were made after 2015
long_range_cars = []
for car in data:
    if int(car[4]) > 100 and int(car[2]) >= 2015:
        long_range_cars.append(car)

# Draw plots to show the distribution between city and electric vehicle type
plt.subplot(2, 2, 1)
plt.title("Distribution of Cars by City")
plt.xlabel("City")
plt.ylabel("Number of Cars")
plt.hist([car[3] for car in data], bins=10)

plt.subplot(2, 2, 2)
plt.title("Distribution of Cars by Electric Vehicle Type")
plt.xlabel("Electric Vehicle Type")
plt.ylabel("Number of Cars")
plt.hist([car[1] for car in data], bins=10)

plt.subplot(2, 2, 3)
plt.title("Distribution of Cars by Model Year")
plt.xlabel("Model Year")
plt.ylabel("Number of Cars")
plt.hist([int(car[2]) for car in data], bins=10)

plt.subplot(2, 2, 4)
plt.title("Distribution of Cars by Electric Range")
plt.xlabel("Electric Range")
plt.ylabel("Number of Cars")
plt.hist([int(car[4]) for car in data], bins=10)

plt.show()
